# %%
from train_util import train_wrapper_util_single_dataset
# train on cross_validation 
data_folder = '/home/jupyter/AQMAR/'
result_folder = '/home/jupyter/result_AQMAR/h128/full/'
train_wrapper_util_single_dataset(data_folder, result_folder, hidden_size = 128, max_epochs = 200)
# Out:
# 2019-04-16 18:48:12,221 this function is deprecated, use smart_open.open instead
# 2019-04-16 18:48:14,455 Reading data from /home/jupyter/AQMAR
# 2019-04-16 18:48:14,456 Train: /home/jupyter/AQMAR/train.txt
# 2019-04-16 18:48:14,457 Dev: /home/jupyter/AQMAR/dev.txt
# 2019-04-16 18:48:14,458 Test: None
# load 10 % of the train data as test dataset
# {b'<unk>': 0, b'O': 1, b'B-PER': 2, b'B-LOC': 3, b'I-PER': 4, b'I-LOC': 5, b'B-MIS': 6, b'I-MIS': 7, b'B-ORG': 8, b'I-ORG': 9, b'<START>': 10, b'<STOP>': 11}
# 2019-04-16 18:48:17,456 ----------------------------------------------------------------------------------------------------
# 2019-04-16 18:48:17,457 Evaluation method: MICRO_F1_SCORE
# 2019-04-16 18:48:17,460 ----------------------------------------------------------------------------------------------------
# 2019-04-16 18:48:17,920 epoch 1 - iter 0/38 - loss 89.35498047
# 2019-04-16 18:48:19,690 epoch 1 - iter 3/38 - loss 74.26527500
# ...

# %%
from_model_to_solution(result_root_folder)

# %%
# !bash run.sh

# do zip and submit
