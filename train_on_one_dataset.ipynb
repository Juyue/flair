# %%
import os
from train_util import train_wrapper_util_cross_val_dataset
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
# train on cross_validation 
data_root_folder = '/home/jupyter/AQMAR/'
result_root_folder = '/home/jupyter/result_AQMAR/'

hidden_size_bank = [160, 192] # another 5~10 hour.
for hidden_size in hidden_size_bank:
    result_folder = os.path.join(result_root_folder, 'h{}'.format(hidden_size))
    train_wrapper_util_cross_val_dataset(data_root_folder, result_folder, hidden_size, max_epochs = 200)
# Out:
# 2019-04-16 18:44:01,293 this function is deprecated, use smart_open.open instead
# 2019-04-16 18:44:03,597 Reading data from /home/jupyter/AQMAR/data_0
# 2019-04-16 18:44:03,599 Train: /home/jupyter/AQMAR/data_0/train.txt
# 2019-04-16 18:44:03,599 Dev: /home/jupyter/AQMAR/data_0/dev.txt
# 2019-04-16 18:44:03,600 Test: None
# load 10 % of the train data as test dataset
# {b'<unk>': 0, b'O': 1, b'B-LOC': 2, b'B-PER': 3, b'B-ORG': 4, b'I-ORG': 5, b'B-MIS': 6, b'I-LOC': 7, b'I-MIS': 8, b'I-PER': 9, b'<START>': 10, b'<STOP>': 11}
# 2019-04-16 18:44:06,508 ----------------------------------------------------------------------------------------------------
# 2019-04-16 18:44:06,510 Evaluation method: MICRO_F1_SCORE
# 2019-04-16 18:44:06,511 ----------------------------------------------------------------------------------------------------
# 2019-04-16 18:44:06,983 epoch 1 - iter 0/31 - loss 53.99659348
# 2019-04-16 18:44:08,047 epoch 1 - iter 3/31 - loss 185.75950146
# ...
